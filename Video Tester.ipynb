# %%
import cv2
import numpy as np
from keras.models import model_from_json
from keras.preprocessing import image

# %%
#load model
model = model_from_json(open("FER.json", "r").read())
#load weights
model.load_weights('fer.h5')

# %%
face_haar_cascade = cv2.CascadeClassifier('haarcascade_frontalface_default.xml')

# %%
cap = cv2.VideoCapture(0)

while(True):
    ret, frame = cap.read()
    if ret is None:
        continue;
    gray_img= cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
    

    faces_detected = face_haar_cascade.detectMultiScale(gray_img, 1.32, 5)
    
    for (x,y,w,h) in faces_detected:
        cv2.rectangle(frame,(x,y),(x+w-10,y+h),(255,0,0),thickness=5)
        roi_gray=gray_img[y:y+h-10,x+20:x+w-30]
        roi_gray=cv2.resize(roi_gray,(48,48))
        img_pixels = image.img_to_array(roi_gray)
        img_pixels = np.expand_dims(img_pixels, axis = 0)
        img_pixels = np.array(img_pixels, 'float32')
        img_pixels /=255
        
        predictions = model.predict(img_pixels)
        
        max_index = np.argmax(predictions[0])

        emotions = ('Angry', 'Fear', 'Happy', 'Sad', 'Surprise', 'Neutral')
        predicted_emotion = emotions[max_index]
        
        cv2.putText(frame, predicted_emotion, (int(x), int(y)), cv2.FONT_HERSHEY_SIMPLEX, 1, (0,0,255), 2)

    resized_img = cv2.resize(frame, (1000, 700))
    cv2.imshow('Facial emotion analysis ',resized_img)

    if cv2.waitKey(100) == ord("e"):
        break
    
cap.release()
cv2.destroyAllWindows()
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# <ipython-input-4-40452fc510ca> in <module>
#      13         cv2.rectangle(frame,(x,y),(x+w-10,y+h),(255,0,0),thickness=5)
#      14         roi_gray=gray_img[y:y+h-10,x+20:x+w-30]
# ---> 15         roi_gray=cv2.resize(roi_gray,(48,48))
#      16         img_pixels = image.img_to_array(roi_gray)
#      17         img_pixels = np.expand_dims(img_pixels, axis = 0)
#
# error: OpenCV(4.5.4-dev) D:\a\opencv-python\opencv-python\opencv\modules\imgproc\src\resize.cpp:4051: error: (-215:Assertion failed) !ssize.empty() in function 'cv::resize'

# %%
def emotion_analysis(emotions):
    objects = ['angry', 'fear', 'happy', 'sad', 'surprise', 'neutral']
    y_pos = np.arange(len(objects))
    plt.bar(y_pos, emotions, align='center', alpha=0.9)
    plt.xticks(y_pos, objects)
    plt.ylabel('percentage')
    plt.title('emotion')
    
    plt.show()

# %%
def process_image(img):
    x = image.img_to_array(img)
    x = np.expand_dims(x, axis = 0)
    x /= 255
    
    return x

# %%
emotions = ['angry', 'fear', 'happy', 'sad', 'surprise', 'neutral']

# %%
img = image.load_img('happy1.jpg', grayscale=True, target_size=(48, 48))
show_img=image.load_img('happy1.jpg', target_size=(200, 200))

x = image.img_to_array(img)
x = np.expand_dims(x, axis = 0)

x /= 255

custom1 = model1.predict(x)
custom2 = model2.predict(x)

# emotion_analysis(custom1[0])
# emotion_analysis(custom2[0])

for i,c in enumerate(custom1):
    custom2[i]+=c;

emotion_analysis(custom2[0])
    
plt.imshow(show_img)
plt.show()
print("Actual emotion: Happy" )
print("Prediction emotion: ", emotions[np.argmax(custom2)])
# Out:
# Actual emotion: Happy
# Prediction emotion:  happy

# %%
img = image.load_img('Surprise1.jpg', grayscale=True, target_size=(48, 48))
show_img=image.load_img('Surprise1.jpg', target_size=(200, 200))

x = image.img_to_array(img)
x = np.expand_dims(x, axis = 0)

x /= 255

custom1 = model1.predict(x)
custom2 = model2.predict(x)

# emotion_analysis(custom1[0])
# emotion_analysis(custom2[0])

for i,c in enumerate(custom1):
    custom2[i]+=c;

emotion_analysis(custom2[0])
    
plt.imshow(show_img)
plt.show()
print("Actual emotion: Surprised" )
print("Prediction emotion: ", emotions[np.argmax(custom2)])
# Out:
# Actual emotion: Surprised
# Prediction emotion:  surprise

# %%
img = image.load_img('fear1.jpg', grayscale=True, target_size=(48, 48))
show_img=image.load_img('fear1.jpg', target_size=(200, 200))

x = image.img_to_array(img)
x = np.expand_dims(x, axis = 0)

x /= 255

custom1 = model1.predict(x)
custom2 = model2.predict(x)

# emotion_analysis(custom1[0])
# emotion_analysis(custom2[0])

for i,c in enumerate(custom1):
    custom2[i]+=c;

emotion_analysis(custom2[0])
    
plt.imshow(show_img)
plt.show()
print("Actual emotion: Fear" )
print("Prediction emotion: ", emotions[np.argmax(custom2)])
# Out:
# Actual emotion: Fear
# Prediction emotion:  surprise

# %%
img = image.load_img('sad1.jpg', grayscale=True, target_size=(48, 48))
show_img=image.load_img('sad1.jpg', target_size=(200, 200))

x = image.img_to_array(img)
x = np.expand_dims(x, axis = 0)

x /= 255

custom1 = model1.predict(x)
custom2 = model2.predict(x)

# emotion_analysis(custom1[0])
# emotion_analysis(custom2[0])

for i,c in enumerate(custom1):
    custom2[i]+=c;

emotion_analysis(custom2[0])
    
plt.imshow(show_img)
plt.show()
print("Actual emotion: Sad" )
print("Prediction emotion: ", emotions[np.argmax(custom2)])


# img = image.load_img('sad1.jpg', grayscale=True, target_size=(48,48))
# x = process_image(img)
# pred = model.predict(x)
# emotion_analysis(pred[0])

# plt.imshow(image.load_img('sad1.jpg'))
# plt.show()
# print("Actual emotion: Sad")
# print("Prediction emotion: ", emotions[np.argmax(pred)])
# Out:
# Actual emotion: Sad
# Prediction emotion:  sad

# %%
img = image.load_img('anger1.jpg', grayscale=True, target_size=(48, 48))
show_img=image.load_img('anger1.jpg', target_size=(200, 200))

x = image.img_to_array(img)
x = np.expand_dims(x, axis = 0)

x /= 255

custom1 = model1.predict(x)
custom2 = model2.predict(x)

# emotion_analysis(custom1[0])
# emotion_analysis(custom2[0])

for i,c in enumerate(custom1):
    custom2[i]+=c;

emotion_analysis(custom2[0])
    
plt.imshow(show_img)
plt.show()
print("Actual emotion: Angry" )
print("Prediction emotion: ", emotions[np.argmax(custom2)])
# Out:
# Actual emotion: Angry
# Prediction emotion:  angry

# %%
img = image.load_img('neutral1.jpg', grayscale=True, target_size=(48, 48))
show_img=image.load_img('neutral1.jpg', target_size=(200, 200))

x = image.img_to_array(img)
x = np.expand_dims(x, axis = 0)

x /= 255

custom1 = model1.predict(x)
custom2 = model2.predict(x)

# emotion_analysis(custom1[0])
# emotion_analysis(custom2[0])

for i,c in enumerate(custom1):
    custom2[i]+=c;

emotion_analysis(custom2[0])
    
plt.imshow(show_img)
plt.show()
print("Actual emotion: Neutral" )
print("Prediction emotion: ", emotions[np.argmax(custom2)])
# Out:
# Actual emotion: Neutral
# Prediction emotion:  neutral

# %%
img = image.load_img('neut1.jpg', grayscale=True, target_size=(48, 48))
show_img=image.load_img('neut1.jpg', target_size=(200, 200))

x = image.img_to_array(img)
x = np.expand_dims(x, axis = 0)

x /= 255

custom1 = model1.predict(x)
custom2 = model2.predict(x)

# emotion_analysis(custom1[0])
# emotion_analysis(custom2[0])

for i,c in enumerate(custom1):
    custom2[i]+=c;

emotion_analysis(custom2[0])
    
plt.imshow(show_img)
plt.show()
print("Actual emotion: Neutral" )
print("Prediction emotion: ", emotions[np.argmax(custom2)])
# Out:
# Actual emotion: Neutral
# Prediction emotion:  neutral

# %%
img = image.load_img('feary1.jpg', grayscale=True, target_size=(48, 48))
show_img=image.load_img('feary1.jpg', target_size=(200, 200))

x = image.img_to_array(img)
x = np.expand_dims(x, axis = 0)

x /= 255

custom1 = model1.predict(x)
custom2 = model2.predict(x)

# emotion_analysis(custom1[0])
# emotion_analysis(custom2[0])

for i,c in enumerate(custom1):
    custom2[i]+=c;

emotion_analysis(custom2[0])
    
plt.imshow(show_img)
plt.show()
print("Actual emotion: Fear" )
print("Prediction emotion: ", emotions[np.argmax(custom2)])
# Out:
# Actual emotion: Fear
# Prediction emotion:  fear
